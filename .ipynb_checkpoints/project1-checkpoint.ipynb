# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
from random import random, seed, randrange
from scipy import stats
from functions1 import *
# %matplotlib inline
seed=1

# %%
x = np.arange(0, 1, 0.01)
y = np.arange(0, 1, 0.01)
#x = np.random.rand(100,1)
#y = np.random.rand(100,1)
#print(x)
#print(y)
x, y = np.meshgrid(x,y)
z = FrankeFunction(x, y) +0.02*np.random.randn(100,100)
fig=plotTheSurface(x,y,z)
fig.show()
#fig.savefig('Franke.png',DPI=(200))
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# #OSL regression

# %%
#transforming to a coluum vector in order to form an x_hat matrix
xVector=np.matrix.flatten(x)
yVector=np.matrix.flatten(y)
#vectorSize=np.size(yVector,0)
zVector=np.matrix.flatten(z)
sizeVector=np.size(zVector)
matrixSize=np.size(y,0)

# %%
indeces1=np.linspace(0,sizeVector-1,sizeVector)
train1,test1=train_test_split(indeces1, 0.7)
train1=train1.astype(int)
test1=test1.astype(int)
beta,Xinv=OSLregression(xVector[train1],yVector[train1],zVector[train1],3)
zPredict=computeZpredict(xVector[test1],yVector[test1],beta,3)
print(MSE(zVector[test1],zPredict))
print(r2score(zVector[test1],zPredict))

# %%
print(beta)
CI=cofidentint(Xinv,zVector[test1],zPredict,beta)
print(CI)

# %%
 
# test cross validation split
indeces=np.linspace(0,sizeVector-1,sizeVector)
indeces=indeces.astype(int)
numberOfFolds=10
folds = k_folds_CV(indeces, numberOfFolds)

polynom_oders=[3,4,5]

# %%
print(sizeVector)

# %%
zPredictmatrix,statsMatrix,betaMatrix=olsModel(polynom_oders,xVector,yVector,zVector,numberOfFolds,folds,indeces)
# Out:
# STATS of MSE for polynom order 3 is:
# DescribeResult(nobs=10, minmax=(0.0071462310071305855, 0.00912190838153223), mean=0.008114115236598862, variance=3.002244944686032e-07, skewness=0.03439239188986463, kurtosis=-0.21003721191761837)
# STATS of R2score for polynom order 3 is:
# DescribeResult(nobs=10, minmax=(0.8929502127989541, 0.9098965172676208), mean=0.902157734586131, variance=2.1896146863086557e-05, skewness=-0.24104877476144038, kurtosis=-0.02026152447870322)
#
#
# STATS of MSE for polynom order 4 is:
# DescribeResult(nobs=10, minmax=(0.004111092591848804, 0.004711623949930211), mean=0.004367960332706174, variance=4.154070039658727e-08, skewness=0.2328187234927805, kurtosis=-1.1958388162301652)
# STATS of R2score for polynom order 4 is:
# DescribeResult(nobs=10, minmax=(0.9446948620069963, 0.9512578291136954), mean=0.9472938859130196, variance=3.734786064473281e-06, skewness=0.5126929531337177, kurtosis=-0.03682123707500873)
#
#
# STATS of MSE for polynom order 5 is:
# DescribeResult(nobs=10, minmax=(0.002294064837502686, 0.0026720027393420517), mean=0.0024702318598263037, variance=1.6181301617573665e-08, skewness=0.3384466883321355, kurtosis=-1.154221379996605)
# STATS of R2score for polynom order 5 is:
# DescribeResult(nobs=10, minmax=(0.9686371033261761, 0.9721707666251926), mean=0.9701952820371897, variance=1.3649517809975937e-06, skewness=0.16332898268867976, kurtosis=-1.1282958526229723)

# %%
bias,var=computeBiasandVar(zPredictmatrix[:,:,2],zVector)
print('Bias^2 for the final model is: ' + str(bias))
print('Var for the final model is: ' + str(var))
beta1=np.mean(betaMatrix[:,:,2],1)
z_pred=computeZpredict(xVector,yVector,beta1,5)
matrixSize=np.size(y,0)
zPredictReshape=np.reshape(z_pred,(matrixSize,matrixSize))
fig1=plotTheSurface(x,y,zPredictReshape)
fig1.show()
#fig1.savefig('olsFranke.png')
print(str(MSE(z_pred,zVector)))
print(bias + var)
# Out:
# Bias^2 for the final model is: 0.0024548312001895726
# Var for the final model is: 7.218160635367331e-07
# 0.0024548312001895765
# 0.002455553016253109
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
from sklearn.linear_model import Lasso
lassoreg = Lasso(alpha=0.0001,normalize=True)
lassoreg.fit(xMatrix,zVector)
z_pred = lassoreg.predict(xMatrix)

# %%
from sklearn.linear_model import Ridge
xMatrix=constructX(xVector,yVector,3)
ridgereg = Ridge(alpha=0.001,fit_intercept=True)
ridgereg.fit(xMatrix,zVector)
z_pred = ridgereg.predict(xMatrix)
print(MSE(zVector,z_pred))
print(r2score(zVector,z_pred))
print(ridgereg.coef_)
print(ridgereg.intercept_)

# %%
beta,xx=Ridgeregression(xVector,yVector,zVector,3,0.001)
zPredictmatrix=computeZpredict(xVector,yVector,beta,3)
MSE1=MSE(zVector,zPredictmatrix)
r2score1=r2score(zVector,zPredictmatrix)
print(MSE1)
print(r2score1)
print(beta)

# %%
#printing results
lambda_values=[1e-3,1e-2,1e-1,1,10,1e2]
zPredictmatrix,statsMatrix,betaMatrix=ridge_regress(lambda_values,polynom_oders,xVector,yVector,zVector,numberOfFolds,folds,indeces)
for j,order in enumerate(polynom_oders):
    for  h,lbd in enumerate(lambda_values): 
        print(lbd)
        print('Average of MSE for polynom order {} is:'.format(str(order)) + str(np.mean(statsMatrix[0,:,h,j])))
        print('Average of R2score for polynom order {} is:'.format(str(order)) + str(np.mean(statsMatrix[1,:,h,j])))
        print('\n')

beta1=np.mean(betaMatrix[:,:,0,2],1)
z_pred=computeZpredict(xVector,yVector,beta1,5)
bias,var=computeBiasandVar(zPredictmatrix[:,:,0,2],zVector)
print('Bias for the final model is: ' + str(bias))
print('Var for the final model is: ' + str(var))

matrixSize=np.size(y,0)
zPredictReshape=np.reshape(z_pred,(matrixSize,matrixSize))
#fig2=plotTheSurface(x,y,zPredictReshape)
#fig2.show()
#fig2.savefig('RidgeFranke.png',DPI=(200))  
print(str(MSE(z_pred,zVector)))
print(bias + var)
# Out:
# 0.001
# Average of MSE for polynom order 3 is:0.008114115768470775
# Average of R2score for polynom order 3 is:0.9021578251221463
#
#
# 0.01
# Average of MSE for polynom order 3 is:0.008114892572540913
# Average of R2score for polynom order 3 is:0.9021493181365191
#
#
# 0.1
# Average of MSE for polynom order 3 is:0.008184313032223002
# Average of R2score for polynom order 3 is:0.9013197278922117
#
#
# 1
# Average of MSE for polynom order 3 is:0.010169432930821348
# Average of R2score for polynom order 3 is:0.8774117783660135
#
#
# 10
# Average of MSE for polynom order 3 is:0.01604161283171361
# Average of R2score for polynom order 3 is:0.8066223872026125
#
#
# 100.0
# Average of MSE for polynom order 3 is:0.02339630537906095
# Average of R2score for polynom order 3 is:0.7182785799365118
#
#
# 0.001
# Average of MSE for polynom order 4 is:0.004373376325880244
# Average of R2score for polynom order 4 is:0.9472320298658676
#
#
# 0.01
# Average of MSE for polynom order 4 is:0.004697204319499065
# Average of R2score for polynom order 4 is:0.9433468050850419
#
#
# 0.1
# Average of MSE for polynom order 4 is:0.0071513875459536195
# Average of R2score for polynom order 4 is:0.9137778268294022
#
#
# 1
# Average of MSE for polynom order 4 is:0.009119139381525646
# Average of R2score for polynom order 4 is:0.890071009727149
#
#
# 10
# Average of MSE for polynom order 4 is:0.013755288424313375
# Average of R2score for polynom order 4 is:0.8342118596690588
#
#
# 100.0
# Average of MSE for polynom order 4 is:0.022530280357546655
# Average of R2score for polynom order 4 is:0.7287175113487478
#
#
# 0.001
# Average of MSE for polynom order 5 is:0.002762459366758355
# Average of R2score for polynom order 5 is:0.9666671443201963
#
#
# 0.01
# Average of MSE for polynom order 5 is:0.0038877427997758103
# Average of R2score for polynom order 5 is:0.9530994120696856
#
#
# 0.1
# Average of MSE for polynom order 5 is:0.005696182179589724
# Average of R2score for polynom order 5 is:0.9313209084690379
#
#
# 1
# Average of MSE for polynom order 5 is:0.008888935362773569
# Average of R2score for polynom order 5 is:0.8928447337799058
#
#
# 10
# Average of MSE for polynom order 5 is:0.012439997604434132
# Average of R2score for polynom order 5 is:0.850077584818543
#
#
# 100.0
# Average of MSE for polynom order 5 is:0.021595050633788217
# Average of R2score for polynom order 5 is:0.7399930026970355
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-85a6545d43ec> in <module>()
#      10
#      11 beta1=np.mean(betaMatrix[:,:,0,2],1)
# ---> 12 z_pred=computeZpredict(xVector,yVector,beta1,5)
#      13 bias,var=computeBiasandVar(zPredictmatrix[:,:,0,2],zVector)
#      14 print('Bias for the final model is: ' + str(bias))
#
# ~/Documents/GitHub/MachineLearning dave/assignment1/functions1.py in computeZpredict(xVector, yVector, beta, polyOrder)
#      83     #
#      84     xMatrix=constructX(xVector,yVector,polyOrder)
# ---> 85     zPredict=xMatrix.dot(beta)
#      86     return zPredict
#      87
#
# ValueError: shapes (10000,21) and (34,) not aligned: 21 (dim 1) != 34 (dim 0)

# %%
print(betaMatrix[:,:,0,2])

# %%
lambda_values=[1e-3,1e-2,1e-1,1,10,1e2]
zPredictmatrix,statsMatrix,betaMatrix=lassoRegress(lambda_values,polynom_oders,xVector,yVector,zVector,numberOfFolds,folds,indeces)
for j,order in enumerate(polynom_oders):
    for  h,lbd in enumerate(lambda_values): 
        print(lbd)
        print('Average of MSE for polynom order {} is:'.format(str(order)) + str(np.mean(statsMatrix[0,:,h,j])))
        print('Average of R2score for polynom order {} is:'.format(str(order)) + str(np.mean(statsMatrix[1,:,h,j])))
        print('\n')

# %%
beta1=np.mean(betaMatrix[:,:,0,2],1)
z_pred=computeZpredict(xVector,yVector,beta1,5)
bias,var=computeBiasandVar(zPredictmatrix[:,:,0,2],zVector)
print('Bias for the final model is: ' + str(bias))
print('Var for the final model is: ' + str(var))
matrixSize=np.size(y,0)
zPredictReshape=np.reshape(z_pred,(matrixSize,matrixSize))
#fig2=plotTheSurface(x,y,zPredictReshape)
#fig2.show()
#fig2.savefig('LassoFranke.png')
print(str(MSE(z_pred,zVector)))
print(bias + var)

# %%
print(betaMatrix[:,:,0,2])
